# %% [markdown]
# # 05 Error Analysis
#
# Inspect baseline and transformer failures, especially on code-switched, short, or negation-heavy comments.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src.data_utils import build_paths

paths = build_paths()
baseline_preds = pd.read_csv(paths.results_dir / 'baseline_predictions.csv')
baseline_errors = baseline_preds[baseline_preds['true_label'] != baseline_preds['predicted_label']]
baseline_errors.head(20)
# Out:
#                                                  text  \
# 2   Zikatero boma la DPP limukorekole, ma mafia am...
# 6                                Dowa on map iwe 🔥🔥🔥🔥
# 15  All the way from republic of DOWA aaaaa this m...
# 18              Napoleon Grasshoppers, thinks like AI
# 21  I hate politicians...mbava zomwe zikulowesa pa...
# 22                             Amuna chisale pamakina
# 23                            Basi kudowa mdikumalawi
# 35                         Napolion ndiboma palokha✌️
# 37                                Work up malawiiiiii
# 40  I'm proud of being Chewa. Sindale, I am just t...
# 44  Pomwe wina has been an MP for more than 15 yea...
# 49                                God bless Malawi 🇲🇼
# 56                            The news we lov to hear
#
#                                          cleaned_text true_label  \
# 2   zikatero boma la dpp limukorekole , ma mafia a...   negative
# 6                                dowa on map iwe 🔥🔥🔥🔥   positive
# 15  all the way from republic of dowa aaaaa this m...   positive
# 18             napoleon grasshoppers , thinks like ai    neutral
# 21  i hate politicians...mbava zomwe zikulowesa pa...   negative
# 22                             amuna chisale pamakina    neutral
# 23                            basi kudowa mdikumalawi    neutral
# 35                         napolion ndiboma palokha✌️    neutral
# 37                                work up malawiiiiii    neutral
# 40  i ' m proud of being chewa. sindale , i am jus...   negative
# 44  pomwe wina has been an mp for more than <num> ...   negative
# 49                                god bless malawi 🇲🇼    neutral
# 56                            the news we lov to hear    neutral
#
#    predicted_label
# 2         positive
# 6          neutral
# 15        negative
# 18        positive
# 21        positive
# 22        positive
# 23        positive
# 35        positive
# 37        positive
# 40        positive
# 44        positive
# 49        positive
# 56        positive

# %%
baseline_preds['predicted_label'].value_counts()
# Out:
# predicted_label
# positive    54
# neutral      2
# negative     1
# Name: count, dtype: int64

# %%
baseline_preds['true_label'].value_counts()
# Out:
# true_label
# positive    45
# neutral      8
# negative     4
# Name: count, dtype: int64

# %%
baseline_errors[baseline_errors['text'].str.contains('not|no|ayi|osati', case=False, na=False)].head(20)
# Out:
#                                                  text  \
# 21  I hate politicians...mbava zomwe zikulowesa pa...
#
#                                          cleaned_text true_label  \
# 21  i hate politicians...mbava zomwe zikulowesa pa...   negative
#
#    predicted_label
# 21        positive
