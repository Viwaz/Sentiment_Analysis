# %% [markdown]
# # 05 Error Analysis
#
# Inspect baseline and transformer failures, especially on code-switched, short, or negation-heavy comments.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src.data_utils import build_paths

paths = build_paths()
baseline_preds = pd.read_csv(paths.results_dir / 'baseline_predictions.csv')
baseline_errors = baseline_preds[baseline_preds['true_label'] != baseline_preds['predicted_label']]
baseline_errors.head(20)
# Out:
#                                                  text  \
# 0                   Uyu akuposa Mr 6 billion kuganiza
# 1               He's an answer than Malawi government
# 6                                     Kumaliwopa mawa
# 7              A police anjoye inde salary ndiyochepa
# 8   Ndani ankadziwa kuti filling station padzakhar...
# 9           mukamapanga zanuzo ine musandiwelengele😅💔
# 11                                  400 million USD 🥹
# 12         Mkulukuta moyo akubwela ndizelu dzausilutu
# 16                          naye wa police ndi munthu
# 19   4 million litres plus, ndimafuta ochepa kwambili
# 21                          Koma zikuchitikadi izizi?
# 22            Boma ilooo alekeni agalu kuuwa ndi kwao
# 23                                A police aphula apa
# 33  We've been there, done that but it always ende...
# 35  Aaaaaa police basi busy zimenezo? U guy can do...
# 41  Still will never help coz anthuwa amathira ful...
# 44                                  Iwowo ndi boma? 😂
# 45                                  The same old song
# 50      Code kampani ya maheu ija ili kut inu a mcp..
# 51  Mesa kuyambira  mawa akhala akupezeka  filling...
#
#                                          cleaned_text true_label  \
# 0               uyu akuposa mr <num> billion kuganiza   positive
# 1             he ' s an answer than malawi government   positive
# 6                                     kumaliwopa mawa    neutral
# 7              a police anjoye inde salary ndiyochepa    neutral
# 8   ndani ankadziwa kuti filling station padzakhar...   negative
# 9   mukamapanga zanuzo ine musandiwelengele😅💔 emoj...    neutral
# 11  <num> million usd 🥹 emoji_face_holding_back_tears    neutral
# 12         mkulukuta moyo akubwela ndizelu dzausilutu   negative
# 16                          naye wa police ndi munthu    neutral
# 19  <num> million litres plus , ndimafuta ochepa k...    neutral
# 21                          koma zikuchitikadi izizi?    neutral
# 22            boma ilooo alekeni agalu kuuwa ndi kwao   positive
# 23                                a police aphula apa    neutral
# 33  we ' ve been there , done that but it always e...    neutral
# 35  aaaaaa police basi busy zimenezo? u guy can do...    neutral
# 41  still will never help coz anthuwa amathira ful...   negative
# 44     iwowo ndi boma? 😂 emoji_face_with_tears_of_joy    neutral
# 45                                  the same old song    neutral
# 50      code kampani ya maheu ija ili kut inu a mcp..    neutral
# 51  mesa kuyambira mawa akhala akupezeka filling s...   negative
#
#    predicted_label
# 0         negative
# 1          neutral
# 6         negative
# 7         negative
# 8          neutral
# 9         negative
# 11        negative
# 12         neutral
# 16        negative
# 19        negative
# 21        negative
# 22        negative
# 23        negative
# 33        negative
# 35        positive
# 41         neutral
# 44        negative
# 45        negative
# 50        negative
# 51         neutral

# %%
baseline_preds['predicted_label'].value_counts()
# Out:
# predicted_label
# negative    188
# neutral      29
# positive      7
# Name: count, dtype: int64

# %%
baseline_preds['true_label'].value_counts()
# Out:
# true_label
# negative    151
# neutral      52
# positive     21
# Name: count, dtype: int64

# %%
baseline_errors[baseline_errors['text'].str.contains('not|no|ayi|osati', case=False, na=False)].head(20)
# Out:
#                                                   text  \
# 52   Mbali yakuno kulibe chithu cha 20kwacha ky kwa...
# 65                         Mcp inaononga dziko lathuli
# 70   Good move \r\nPolice officers athandiza just b...
# 78   Bola tikudya nsima anthu sangamalimbirane mafu...
# 106  Tiyambira wa police yooo kuledzeresa, it's not...
# 109  Tangobweletsani fuel basi adzipezeka. Taimbani...
# 118  First paragraph - Question - WHAT DELIVERY? Al...
# 132                              Ine pa shop panga ayi
# 135             Do we know  what we want as a country?
# 180  A Malawi yemwe anatiloza anamwalira. Inu adind...
# 187  Boma lokanika ili mpakana apolice muma filling...
# 222  Mfuti ija idzakonza zinthu kuno...kunachuluka ...
# 223                                         Ayi zikomo
#
#                                           cleaned_text true_label  \
# 52   mbali yakuno kulibe chithu cha 20kwacha ky kwa...   positive
# 65                         mcp inaononga dziko lathuli    neutral
# 70   good move police officers athandiza just be vi...   positive
# 78   bola tikudya nsima anthu sangamalimbirane mafu...    neutral
# 106  tiyambira wa police yooo kuledzeresa , it ' s ...    neutral
# 109  tangobweletsani fuel basi adzipezeka. taimbani...   negative
# 118  first paragraph - question - what delivery? al...   negative
# 132                              ine pa shop panga ayi   negative
# 135              do we know what we want as a country?   positive
# 180  a malawi yemwe anatiloza anamwalira. inu adind...   negative
# 187  boma lokanika ili mpakana apolice muma filling...   negative
# 222  mfuti ija idzakonza zinthu kuno...kunachuluka ...    neutral
# 223                                         ayi zikomo    neutral
#
#     predicted_label
# 52         negative
# 65         negative
# 70         negative
# 78         negative
# 106        negative
# 109         neutral
# 118        positive
# 132         neutral
# 135        negative
# 180         neutral
# 187         neutral
# 222        negative
# 223        negative
