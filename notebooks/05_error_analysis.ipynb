# %% [markdown]
# # 05 Error Analysis
#
# Inspect baseline and transformer failures, especially on code-switched, short, or negation-heavy comments.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src.data_utils import build_paths

paths = build_paths()
baseline_preds = pd.read_csv(paths.results_dir / 'baseline_predictions.csv')
baseline_errors = baseline_preds[baseline_preds['true_label'] != baseline_preds['predicted_label']]
baseline_errors.head(20)
# Out:
#                                                  text  \
# 4                                    Munkatha mawu tu
# 7   Chancy Rabson Fact, in fact I blame myself for...
# 9   Mbali yakuno kulibe chithu cha 20kwacha ky kwa...
# 12  In fact they are the worst than what you are t...
# 13                              First time to hear it
# 15  TAM is too corrupt, mwalandila howo mukatelo.....
# 16  This another way of saying mabvuto a fuel alip...
# 19                               Aziwalipila amerawo?
# 21                           Zafikatu pa nabola nsima
# 24  You speaking for Nocma! Update us when the fue...
# 26  Tangobweletsani fuel basi adzipezeka. Taimbani...
# 27  Ingobwelesani fuel wokwanila, otherwise deploy...
# 31  Kodi lameck nayeso ali ndi mphamvu yomatipatsa...
# 33  Hamayo ndalama ija yatha mphamvuu bc ana anga ...
# 36                  Chakwera ankatichedwesa ma guy 😌😌
# 38                                     Zeru za bamboo
# 40                                        Kkkkkkkkkkk
# 41                                    Wanunkha malawi
# 42                                    Muzimulipila et
# 43                         Napolion ndiboma palokha✌️
#
#                                          cleaned_text true_label  \
# 4                                    munkatha mawu tu    neutral
# 7   chancy rabson fact , in fact i blame myself fo...    neutral
# 9   mbali yakuno kulibe chithu cha 20kwacha ky kwa...   positive
# 12  in fact they are the worst than what you are t...   negative
# 13                              first time to hear it    neutral
# 15  tam is too corrupt , mwalandila howo mukatelo....    neutral
# 16  this another way of saying mabvuto a fuel alip...   negative
# 19                               aziwalipila amerawo?    neutral
# 21                           zafikatu pa nabola nsima   negative
# 24  you speaking for nocma! update us when the fue...   positive
# 26  tangobweletsani fuel basi adzipezeka. taimbani...   negative
# 27  ingobwelesani fuel wokwanila , otherwise deplo...   negative
# 31  kodi lameck nayeso ali ndi mphamvu yomatipatsa...    neutral
# 33  hamayo ndalama ija yatha mphamvuu bc ana anga ...   positive
# 36  chakwera ankatichedwesa ma guy 😌😌 emoji_reliev...   positive
# 38                                     zeru za bamboo    neutral
# 40                                        kkkkkkkkkkk   negative
# 41                                    wanunkha malawi   negative
# 42                                    muzimulipila et    neutral
# 43      napolion ndiboma palokha✌️ emoji_victory_hand    neutral
#
#    predicted_label
# 4         negative
# 7         positive
# 9         negative
# 12        positive
# 13        positive
# 15        negative
# 16         neutral
# 19        negative
# 21         neutral
# 24        negative
# 26         neutral
# 27         neutral
# 31        negative
# 33        negative
# 36        negative
# 38        positive
# 40         neutral
# 41         neutral
# 42        negative
# 43        positive

# %%
baseline_preds['predicted_label'].value_counts()
# Out:
# predicted_label
# negative    152
# positive     63
# neutral      57
# Name: count, dtype: int64

# %%
baseline_preds['true_label'].value_counts()
# Out:
# true_label
# negative    153
# positive     61
# neutral      58
# Name: count, dtype: int64

# %%
baseline_errors[baseline_errors['text'].str.contains('not|no|ayi|osati', case=False, na=False)].head(20)
# Out:
#                                                   text  \
# 9    Mbali yakuno kulibe chithu cha 20kwacha ky kwa...
# 16   This another way of saying mabvuto a fuel alip...
# 24   You speaking for Nocma! Update us when the fue...
# 26   Tangobweletsani fuel basi adzipezeka. Taimbani...
# 59   Aaaaah zokanika ma deal akupangidwa a police A...
# 77   The true meaning of a Chichewa saying which go...
# 92   Hahahahahah! Deployment of police officers is ...
# 100  Tiyambira wa police yooo kuledzeresa, it's not...
# 107                            Kapokola ananale sopano
# 128  Kod ndiye kut pazikhala allowance kwa a police...
# 135         Ubwino wake akudya ndi aMalawi azathu. ☹️💔
# 138               Repeated stories, nothing is strange
# 142  The fruits of kamuzu Banda, a Malawi ndife a m...
# 150  Mfuti ija idzakonza zinthu kuno...kunachuluka ...
# 170  Tivomereze kuti ndalama tsopano ikuyambira pa ...
# 177  Pamenepa tikhoza kukharano safe than kudalira ...
# 183  Me am not accepting coins😂 ngt ikukanidwa K20 ...
# 223  Anthu kuno mmene amakanila kulandira ndalama y...
# 228  Better now,\r\nMumanyanya kufupa ma 50 kwacha ...
# 241     Ndiye k20 kwacha paja panopa ikumagula chani ?
#
#                                           cleaned_text true_label  \
# 9    mbali yakuno kulibe chithu cha 20kwacha ky kwa...   positive
# 16   this another way of saying mabvuto a fuel alip...   negative
# 24   you speaking for nocma! update us when the fue...   positive
# 26   tangobweletsani fuel basi adzipezeka. taimbani...   negative
# 59   aaaaah zokanika ma deal akupangidwa a police a...    neutral
# 77   the true meaning of a chichewa saying which go...   negative
# 92   hahahahahah! deployment of police officers is ...   negative
# 100  tiyambira wa police yooo kuledzeresa , it ' s ...    neutral
# 107                            kapokola ananale sopano   negative
# 128  kod ndiye kut pazikhala allowance kwa a police...   positive
# 135  ubwino wake akudya ndi amalawi azathu. ☹️💔 emo...    neutral
# 138              repeated stories , nothing is strange    neutral
# 142  the fruits of kamuzu banda , a malawi ndife a ...   positive
# 150  mfuti ija idzakonza zinthu kuno...kunachuluka ...    neutral
# 170  tivomereze kuti ndalama tsopano ikuyambira pa ...    neutral
# 177  pamenepa tikhoza kukharano safe than kudalira ...   negative
# 183  me am not accepting coins😂 ngt ikukanidwa k20 ...   positive
# 223  anthu kuno mmene amakanila kulandira ndalama y...   positive
# 228  better now , mumanyanya kufupa ma <num> kwacha...   positive
# 241     ndiye k20 kwacha paja panopa ikumagula chani ?   negative
#
#     predicted_label
# 9          negative
# 16          neutral
# 24         negative
# 26          neutral
# 59         negative
# 77         positive
# 92          neutral
# 100        negative
# 107         neutral
# 128        negative
# 135        negative
# 138        positive
# 142        negative
# 150        negative
# 170        negative
# 177         neutral
# 183        negative
# 223        negative
# 228         neutral
# 241         neutral
