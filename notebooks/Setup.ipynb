# %%
# Cloning the repository into the colab environment and changing the directory to the repository
# !git clone https://github.com/Viwaz/Sentiment_Analysis.git # RUN ONCE
# %cd Sentiment_Analysis
# !pip install -r requirements.txt
# !dir
# Out:
# Cloning into 'Sentiment_Analysis'...
# remote: Enumerating objects: 437, done.
# remote: Counting objects: 100% (437/437), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 437 (delta 243), reused 366 (delta 201), pack-reused 0 (from 0)
# Receiving objects: 100% (437/437), 2.82 MiB | 20.23 MiB/s, done.
# Resolving deltas: 100% (243/243), done.
# /content/Sentiment_Analysis
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 15.4 MB/s eta 0:00:0000:01
# ...
# AfriBerta_Testing.ipynb  README.md
# COLAB_AFRIBERTA.md	 reports
# data			 requirements.txt
# GROUP_4_DS_SRS_V7.pdf	 src
# models			 TEAM_PROJECT_STRUCTURE_AND_WORKFLOW_DOCUMENT.md
# notebooks		 viewing.ipynb

# %%
# !git status
# Out:
# On branch 'Trials'
# Your branch is up to date with 'origin/'Trials''.
#
# nothing to commit, working tree clean

# %%
# !git add reports/results/afriberta_small_metrics.json \
         reports/results/afriberta_small_predictions.csv \
         reports/figures/afriberta_small_confusion_matrix.png \
         reports/results/model_comparison.csv
# !git commit -m "Updated results and figures for Afriberta Small model"
# Out:
# ['Trials' 6409099] Updated results and figures for Afriberta Small model
#  4 files changed, 314 insertions(+)
#  create mode 100644 reports/figures/afriberta_small_confusion_matrix.png
#  create mode 100644 reports/results/afriberta_small_metrics.json
#  create mode 100644 reports/results/afriberta_small_predictions.csv

# %%
from getpass import getpass
import os

os.environ["GITHUB_TOKEN"] = getpass("Paste GitHub token: ")

# %%
# !git remote -v
# Out:
# origin	https://x-access-token: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@github.com/Viwaz/Sentiment_Analysis.git (fetch)
# origin	https://x-access-token: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@github.com/Viwaz/Sentiment_Analysis.git (push)

# %%
# !git remote set-url origin https://x-access-token:$GITHUB_TOKEN@github.com/Viwaz/Sentiment_Analysis.git

# %%
# !git commit -m "Add AfriBERTa small evaluation results"
# !git push
# Out:
# Enumerating objects: 14, done.
# Counting objects: 100% (14/14), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 56.03 KiB | 8.00 MiB/s, done.
# Total 9 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/Viwaz/Sentiment_Analysis.git
#    12a4e3a..6409099  'Trials' -> 'Trials'

# %%
# !git config user.email "vdcchima@gmail.com"
# !git config user.name "Viwaz"

# %%
# !git remote set-url origin https://x-access-token:$GITHUB_TOKEN@github.com/Viwaz/Sentiment_Analysis.git
# !git push
# Out:
# remote: Permission to Viwaz/Sentiment_Analysis.git denied to Viwaz.
# fatal: unable to access 'https://github.com/Viwaz/Sentiment_Analysis.git/': The requested URL returned error: 403
