# %% [markdown]
# # 06 External Evaluation
#
# Evaluate the trained baseline on a separate external test dataset without mixing it into training.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.evaluate_external import evaluate_external_baseline

summary = evaluate_external_baseline()
summary
# Out:
# {'dataset_rows': 304,
#  'label_distribution': {'positive': 183, 'neutral': 83, 'negative': 38},
#  'metrics': {'accuracy': 0.3782894736842105,
#   'macro_f1': 0.3572261072261072,
#   'per_class': {'negative': {'precision': 0.14583333333333334,
#     'recall': 0.5526315789473685,
#     'f1': 0.23076923076923078,
#     'support': 38},
#    'neutral': {'precision': 0.34177215189873417,
#     'recall': 0.3253012048192771,
#     'f1': 0.3333333333333333,
#     'support': 83},
#    'positive': {'precision': 0.8271604938271605,
#     'recall': 0.366120218579235,
#     'f1': 0.5075757575757576,
#     'support': 183}},
#   'classification_report': {'negative': {'precision': 0.14583333333333334,
#     'recall': 0.5526315789473685,
#     'f1-score': 0.23076923076923078,
#     'support': 38.0},
#    'neutral': {'precision': 0.34177215189873417,
#     'recall': 0.3253012048192771,
#     'f1-score': 0.3333333333333333,
#     'support': 83.0},
#    'positive': {'precision': 0.8271604938271605,
# ...

# %%
import pandas as pd
from src.data_utils import build_paths

paths = build_paths()
preds = pd.read_csv(paths.results_dir / 'external_baseline_predictions.csv')
preds[preds['true_label'] != preds['predicted_label']].head(20)
# Out:
#                                                  text  \
# 2       Koma ndiyambe kulimbikila😂 iziz bwezi ndilipo
# 3                         Ayamba bwanji ife titachoka
# 4   Christina Malango ukapanda kuwina izi nditsits...
# 5   Hannah Tifanny Chiphwanya wasephan ndimakobili...
# 6   Apa goodson scholarship yatheka osachitaso kufusa
# 8                              Chinthuchi tutenga..🤗🤗
# 11  Wakisa Clouds CLEMENT NGAMBI Jr. Harris Dgr Le...
# 12                    Mtende Munthali iphuleni madala
# 14               Aliah Ommar  chinthuchi tikutenga🔥😂😂
# 15          El Muchacho Mafialah dzina lanu lasowa🤣🤣🤣
# 16               Shaaa odii nane nkhale yazzah 🙌🏾🙌🏾🙌🏾
# 17  Kenegrecha Nelson  zufunika next sem tikaikane...
# 19  Felix Chimowa  chabwno alarm yanu tikhala ndfe...
# 20        Rahim Abdullah mbali ya kumeneko Zikumveka?
# 22  Debbie Tambala muyambe kupezeka pa Dean's List...
# 23  Zabwera mochedwa, eni ake apa deans list tinal...
# ...

# %%
import pandas as pd
comp = pd.read_csv(paths.results_dir / 'model_comparison.csv')
comp.sort_values(by='macro_f1', ascending=False)
# Out:
#     model_family                 model_name          feature_set  \
# 4   classical_ml                 linear_svm           char_tfidf
# 5   classical_ml        logistic_regression       combined_tfidf
# 6   classical_ml        logistic_regression           char_tfidf
# 7   classical_ml                 linear_svm           word_tfidf
# 8   classical_ml                 linear_svm       combined_tfidf
# 9   classical_ml        logistic_regression           word_tfidf
# 1    transformer  castorini/afriberta_small  subword_transformer
# 10  classical_ml              complement_nb           word_tfidf
# 2   classical_ml   best_baseline:linear_svm           char_tfidf
# 11  classical_ml              complement_nb       combined_tfidf
# 12  classical_ml              complement_nb           char_tfidf
# 3    transformer           xlm-roberta-base  subword_transformer
# 13  classical_ml             multinomial_nb           char_tfidf
# ...
