# %% [markdown]
# # 04 Transformer Training
#
# Fine-tune a multilingual transformer on the same fixed splits used by the baselines.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.train_transformer import train_transformer

summary = train_transformer()
summary
# Out:
# Loading tokenizer: castorini/afriberta_small
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/257 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/1.55M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Tokenizing processed splits.
# Map:   0%|          | 0/1040 [00:00<?, ? examples/s]
# Map:   0%|          | 0/223 [00:00<?, ? examples/s]
# Map:   0%|          | 0/224 [00:00<?, ? examples/s]
# Loading model weights: castorini/afriberta_small
# pytorch_model.bin:   0%|          | 0.00/333M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/333M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/69 [00:00<?, ?it/s]
# XLMRobertaForSequenceClassification LOAD REPORT from: castorini/afriberta_small
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.decoder.weight          | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.decoder.bias            | UNEXPECTED |
# classifier.dense.weight         | MISSING    |
# classifier.dense.bias           | MISSING    |
# classifier.out_proj.bias        | MISSING    |
# classifier.out_proj.weight      | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Computing class weights.
# Starting training run: castorini_afriberta_small
# `logging_dir` is deprecated and will be removed in v5.2. Please set `TENSORBOARD_LOGGING_DIR` instead.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='650' max='650' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [650/650 31:30, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Macro F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.126462</td>
#       <td>0.506726</td>
#       <td>0.311850</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.213643</td>
#       <td>0.515695</td>
#       <td>0.328708</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.235096</td>
#       <td>0.582960</td>
#       <td>0.387525</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.908213</td>
#       <td>1.324396</td>
#       <td>0.587444</td>
#       <td>0.393249</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.908213</td>
#       <td>1.392612</td>
#       <td>0.529148</td>
#       <td>0.358081</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# There were missing keys in the checkpoint model loaded: ['roberta.embeddings.LayerNorm.weight', 'roberta.embeddings.LayerNorm.bias', 'roberta.encoder.layer.0.attention.output.LayerNorm.weight', 'roberta.encoder.layer.0.attention.output.LayerNorm.bias', 'roberta.encoder.layer.0.output.LayerNorm.weight', 'roberta.encoder.layer.0.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.weight', 'roberta.encoder.layer.1.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.LayerNorm.weight', 'roberta.encoder.layer.1.output.LayerNorm.bias', 'roberta.encoder.layer.2.attention.output.LayerNorm.weight', 'roberta.encoder.layer.2.attention.output.LayerNorm.bias', 'roberta.encoder.layer.2.output.LayerNorm.weight', 'roberta.encoder.layer.2.output.LayerNorm.bias', 'roberta.encoder.layer.3.attention.output.LayerNorm.weight', 'roberta.encoder.layer.3.attention.output.LayerNorm.bias', 'roberta.encoder.layer.3.output.LayerNorm.weight', 'roberta.encoder.layer.3.output.LayerNorm.bias'].
# There were unexpected keys in the checkpoint model loaded: ['roberta.embeddings.LayerNorm.beta', 'roberta.embeddings.LayerNorm.gamma', 'roberta.encoder.layer.0.attention.output.LayerNorm.beta', 'roberta.encoder.layer.0.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.0.output.LayerNorm.beta', 'roberta.encoder.layer.0.output.LayerNorm.gamma', 'roberta.encoder.layer.1.attention.output.LayerNorm.beta', 'roberta.encoder.layer.1.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.1.output.LayerNorm.beta', 'roberta.encoder.layer.1.output.LayerNorm.gamma', 'roberta.encoder.layer.2.attention.output.LayerNorm.beta', 'roberta.encoder.layer.2.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.2.output.LayerNorm.beta', 'roberta.encoder.layer.2.output.LayerNorm.gamma', 'roberta.encoder.layer.3.attention.output.LayerNorm.beta', 'roberta.encoder.layer.3.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.3.output.LayerNorm.beta', 'roberta.encoder.layer.3.output.LayerNorm.gamma'].
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# {'model_name': 'castorini/afriberta_small',
#  'run_id': 'castorini_afriberta_small',
#  'test_metrics': {'accuracy': 0.5625,
#   'macro_f1': 0.36003256003256,
#   'per_class': {'negative': {'precision': 0.6890243902439024,
#     'recall': 0.7483443708609272,
#     'f1': 0.7174603174603175,
#     'support': 151},
#    'neutral': {'precision': 0.2564102564102564,
#     'recall': 0.19230769230769232,
#     'f1': 0.21978021978021978,
#     'support': 52},
#    'positive': {'precision': 0.14285714285714285,
#     'recall': 0.14285714285714285,
#     'f1': 0.14285714285714285,
#     'support': 21}},
#   'classification_report': {'negative': {'precision': 0.6890243902439024,
#     'recall': 0.7483443708609272,
#     'f1-score': 0.7174603174603175,
#     'support': 151.0},
#    'neutral': {'precision': 0.2564102564102564,
#     'recall': 0.19230769230769232,
#     'f1-score': 0.21978021978021978,
#     'support': 52.0},
#    'positive': {'precision': 0.14285714285714285,
#     'recall': 0.14285714285714285,
#     'f1-score': 0.14285714285714285,
#     'support': 21.0},
#    'accuracy': 0.5625,
#    'macro avg': {'precision': 0.36276392983710054,
#     'recall': 0.36116973534192076,
#     'f1-score': 0.36003256003256,
#     'support': 224.0},
#    'weighted avg': {'precision': 0.5373929297328687,
#     'recall': 0.5625,
#     'f1-score': 0.5480583900226758,
#     'support': 224.0}}},
#  'trainer_metrics': {'test_loss': 1.2610324621200562,
#   'test_accuracy': 0.5625,
#   'test_macro_f1': 0.36003256003256,
#   'test_runtime': 21.4227,
#   'test_samples_per_second': 10.456,
#   'test_steps_per_second': 1.307}}

# %%
# !python -m src.train_transformer --model_name castorini/afriberta_small --run_name afriberta_small
# Out:
# Loading tokenizer: castorini/afriberta_small
# config.json: 100% 730/730 [00:00<00:00, 2.67MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 100% 257/257 [00:00<00:00, 453kB/s]
# sentencepiece.bpe.model: 100% 1.55M/1.55M [00:00<00:00, 38.5MB/s]
# special_tokens_map.json: 100% 150/150 [00:00<00:00, 455kB/s]
# Tokenizing processed splits.
# Map: 100% 1040/1040 [00:00<00:00, 3619.19 examples/s]
# Map: 100% 223/223 [00:00<00:00, 3304.26 examples/s]
# Map: 100% 224/224 [00:00<00:00, 6726.89 examples/s]
# Loading model weights: castorini/afriberta_small
# pytorch_model.bin: 100% 333M/333M [00:01<00:00, 176MB/s]
# Loading weights: 100% 69/69 [00:00<00:00, 3368.84it/s, Materializing param=roberta.encoder.layer.3.output.dense.weight]
# XLMRobertaForSequenceClassification LOAD REPORT from: castorini/afriberta_small
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.decoder.weight          | UNEXPECTED |
# lm_head.decoder.bias            | UNEXPECTED |
# classifier.dense.bias           | MISSING    |
# classifier.out_proj.bias        | MISSING    |
# classifier.out_proj.weight      | MISSING    |
# classifier.dense.weight         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Computing class weights.
# Starting training run: afriberta_small
# `logging_dir` is deprecated and will be removed in v5.2. Please set `TENSORBOARD_LOGGING_DIR` instead.
#   0% 0/650 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#
# model.safetensors:   0% 0.00/333M [00:00<?, ?B/s]
# model.safetensors:   3% 10.5M/333M [00:00<00:04, 75.5MB/s]
# model.safetensors:   6% 21.0M/333M [00:00<00:03, 80.8MB/s]
# model.safetensors:   9% 31.5M/333M [00:00<00:03, 85.3MB/s]
# model.safetensors:  13% 41.9M/333M [00:00<00:03, 78.0MB/s]
# model.safetensors:  16% 52.4M/333M [00:00<00:03, 85.3MB/s]
# model.safetensors:  19% 62.9M/333M [00:00<00:03, 84.1MB/s]
# model.safetensors:  22% 73.4M/333M [00:00<00:03, 86.0MB/s]
# model.safetensors:  25% 83.9M/333M [00:01<00:03, 77.2MB/s]
# model.safetensors:  28% 94.4M/333M [00:01<00:02, 81.6MB/s]
# model.safetensors:  32% 105M/333M [00:01<00:02, 84.4MB/s]
# model.safetensors:  35% 115M/333M [00:01<00:02, 87.1MB/s]
# model.safetensors:  38% 126M/333M [00:01<00:02, 82.0MB/s]
# model.safetensors:  41% 136M/333M [00:01<00:02, 76.2MB/s]
# model.safetensors:  44% 147M/333M [00:01<00:02, 81.9MB/s]
# model.safetensors:  47% 157M/333M [00:01<00:02, 87.1MB/s]
# model.safetensors:  50% 168M/333M [00:02<00:01, 84.6MB/s]
# model.safetensors:  54% 178M/333M [00:02<00:02, 58.1MB/s]
# model.safetensors:  60% 199M/333M [00:02<00:01, 73.2MB/s]
# model.safetensors:  63% 210M/333M [00:02<00:01, 76.1MB/s]
# model.safetensors:  66% 220M/333M [00:02<00:01, 76.1MB/s]
# model.safetensors:  69% 231M/333M [00:02<00:01, 82.0MB/s]
# model.safetensors:  72% 241M/333M [00:03<00:01, 85.3MB/s]
# model.safetensors:  76% 252M/333M [00:03<00:01, 64.4MB/s]
# model.safetensors:  79% 262M/333M [00:03<00:01, 66.6MB/s]
# model.safetensors:  82% 273M/333M [00:03<00:00, 74.4MB/s]
# model.safetensors:  85% 283M/333M [00:03<00:00, 65.7MB/s]
# model.safetensors:  88% 294M/333M [00:04<00:00, 53.6MB/s]
# model.safetensors:  91% 304M/333M [00:04<00:00, 47.4MB/s]
# model.safetensors:  95% 315M/333M [00:04<00:00, 48.6MB/s]
# model.safetensors: 100% 333M/333M [00:04<00:00, 69.7MB/s]
#  20% 130/650 [06:30<16:03,  1.85s/it]
#   0% 0/28 [00:00<?, ?it/s]
#   7% 2/28 [00:00<00:08,  3.03it/s]
#  11% 3/28 [00:00<00:08,  3.12it/s]
#  14% 4/28 [00:01<00:13,  1.79it/s]
#  18% 5/28 [00:02<00:16,  1.36it/s]
#  21% 6/28 [00:04<00:21,  1.01it/s]
#  25% 7/28 [00:05<00:22,  1.07s/it]
#  29% 8/28 [00:06<00:16,  1.22it/s]
#  32% 9/28 [00:06<00:15,  1.22it/s]
#  36% 10/28 [00:07<00:15,  1.13it/s]
#  39% 11/28 [00:08<00:15,  1.12it/s]
#  43% 12/28 [00:09<00:15,  1.06it/s]
#  46% 13/28 [00:10<00:14,  1.01it/s]
#  50% 14/28 [00:12<00:14,  1.02s/it]
#  54% 15/28 [00:12<00:11,  1.10it/s]
#  57% 16/28 [00:13<00:10,  1.15it/s]
#  61% 17/28 [00:14<00:08,  1.29it/s]
#  64% 18/28 [00:14<00:07,  1.32it/s]
#  68% 19/28 [00:15<00:07,  1.26it/s]
#  71% 20/28 [00:17<00:08,  1.07s/it]
#  75% 21/28 [00:18<00:07,  1.11s/it]
#  79% 22/28 [00:19<00:06,  1.00s/it]
#  82% 23/28 [00:19<00:04,  1.18it/s]
#  86% 24/28 [00:20<00:03,  1.28it/s]
#  89% 25/28 [00:20<00:01,  1.53it/s]
#  93% 26/28 [00:21<00:01,  1.57it/s]
#  96% 27/28 [00:21<00:00,  1.57it/s]
#                                      A
# {'eval_loss': '1.064', 'eval_accuracy': '0.574', 'eval_macro_f1': '0.375', 'eval_runtime': '23.45', 'eval_samples_per_second': '9.51', 'eval_steps_per_second': '1.194', 'epoch': '1'}
#  20% 130/650 [06:53<16:03,  1.85s/it]
# 100% 28/28 [00:22<00:00,  1.78it/s]
#
# Writing model shards:   0% 0/1 [00:00<?, ?it/s]
# Writing model shards: 100% 1/1 [00:05<00:00,  5.49s/it]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#  40% 260/650 [13:31<17:04,  2.63s/it]
#   0% 0/28 [00:00<?, ?it/s]
#   7% 2/28 [00:00<00:08,  3.04it/s]
#  11% 3/28 [00:00<00:08,  3.08it/s]
#  14% 4/28 [00:01<00:12,  1.85it/s]
#  18% 5/28 [00:02<00:13,  1.75it/s]
#  21% 6/28 [00:03<00:15,  1.46it/s]
#  25% 7/28 [00:04<00:16,  1.26it/s]
#  29% 8/28 [00:04<00:12,  1.61it/s]
#  32% 9/28 [00:05<00:12,  1.48it/s]
#  36% 10/28 [00:06<00:14,  1.28it/s]
#  39% 11/28 [00:07<00:15,  1.07it/s]
#  43% 12/28 [00:09<00:18,  1.16s/it]
#  46% 13/28 [00:10<00:18,  1.21s/it]
#  50% 14/28 [00:11<00:16,  1.18s/it]
#  54% 15/28 [00:12<00:13,  1.03s/it]
#  57% 16/28 [00:13<00:11,  1.04it/s]
#  61% 17/28 [00:13<00:09,  1.18it/s]
#  64% 18/28 [00:14<00:08,  1.22it/s]
#  68% 19/28 [00:15<00:06,  1.30it/s]
#  71% 20/28 [00:16<00:06,  1.16it/s]
#  75% 21/28 [00:17<00:06,  1.14it/s]
#  79% 22/28 [00:18<00:05,  1.18it/s]
#  82% 23/28 [00:18<00:03,  1.36it/s]
#  86% 24/28 [00:19<00:02,  1.41it/s]
#  89% 25/28 [00:19<00:01,  1.67it/s]
#  93% 26/28 [00:20<00:01,  1.66it/s]
#  96% 27/28 [00:21<00:00,  1.37it/s]
#                                      A
# {'eval_loss': '1.145', 'eval_accuracy': '0.5336', 'eval_macro_f1': '0.3958', 'eval_runtime': '22.93', 'eval_samples_per_second': '9.723', 'eval_steps_per_second': '1.221', 'epoch': '2'}
#  40% 260/650 [13:54<17:04,  2.63s/it]
# 100% 28/28 [00:21<00:00,  1.46it/s]
#
# Writing model shards:   0% 0/1 [00:00<?, ?it/s]
# Writing model shards: 100% 1/1 [00:07<00:00,  7.14s/it]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#  60% 390/650 [20:17<13:17,  3.07s/it]
#   0% 0/28 [00:00<?, ?it/s]
#   7% 2/28 [00:00<00:09,  2.63it/s]
#  11% 3/28 [00:01<00:08,  2.88it/s]
#  14% 4/28 [00:01<00:13,  1.82it/s]
#  18% 5/28 [00:02<00:13,  1.71it/s]
#  21% 6/28 [00:03<00:15,  1.41it/s]
#  25% 7/28 [00:04<00:17,  1.22it/s]
#  29% 8/28 [00:04<00:12,  1.56it/s]
#  32% 9/28 [00:05<00:13,  1.45it/s]
#  36% 10/28 [00:06<00:14,  1.27it/s]
#  39% 11/28 [00:07<00:13,  1.22it/s]
#  43% 12/28 [00:08<00:14,  1.12it/s]
#  46% 13/28 [00:09<00:14,  1.06it/s]
#  50% 14/28 [00:12<00:19,  1.38s/it]
#  54% 15/28 [00:13<00:18,  1.40s/it]
#  57% 16/28 [00:15<00:18,  1.56s/it]
#  61% 17/28 [00:16<00:16,  1.54s/it]
#  64% 18/28 [00:19<00:17,  1.78s/it]
#  68% 19/28 [00:20<00:15,  1.68s/it]
#  71% 20/28 [00:21<00:11,  1.49s/it]
#  75% 21/28 [00:22<00:09,  1.31s/it]
#  79% 22/28 [00:23<00:06,  1.14s/it]
#  82% 23/28 [00:23<00:04,  1.06it/s]
#  86% 24/28 [00:24<00:03,  1.17it/s]
#  89% 25/28 [00:24<00:02,  1.42it/s]
#  93% 26/28 [00:25<00:01,  1.42it/s]
#  96% 27/28 [00:26<00:00,  1.19it/s]
#                                      A
# {'eval_loss': '1.143', 'eval_accuracy': '0.6143', 'eval_macro_f1': '0.4779', 'eval_runtime': '29.08', 'eval_samples_per_second': '7.668', 'eval_steps_per_second': '0.963', 'epoch': '3'}
#  60% 390/650 [20:46<13:17,  3.07s/it]
# 100% 28/28 [00:27<00:00,  1.31it/s]
#
# Writing model shards:   0% 0/1 [00:00<?, ?it/s]
# Writing model shards: 100% 1/1 [00:03<00:00,  3.29s/it]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# {'loss': '0.9391', 'grad_norm': '9.784', 'learning_rate': '4.646e-06', 'epoch': '3.846'}
#  80% 520/650 [27:24<05:39,  2.61s/it]
#   0% 0/28 [00:00<?, ?it/s]
#   7% 2/28 [00:01<00:13,  1.95it/s]
#  11% 3/28 [00:01<00:11,  2.24it/s]
#  14% 4/28 [00:02<00:14,  1.61it/s]
#  18% 5/28 [00:02<00:14,  1.57it/s]
#  21% 6/28 [00:03<00:16,  1.35it/s]
#  25% 7/28 [00:04<00:17,  1.18it/s]
#  29% 8/28 [00:05<00:13,  1.51it/s]
#  32% 9/28 [00:06<00:13,  1.40it/s]
#  36% 10/28 [00:07<00:14,  1.22it/s]
#  39% 11/28 [00:08<00:14,  1.17it/s]
#  43% 12/28 [00:09<00:14,  1.09it/s]
#  46% 13/28 [00:10<00:14,  1.04it/s]
#  50% 14/28 [00:11<00:14,  1.03s/it]
#  54% 15/28 [00:12<00:13,  1.04s/it]
#  57% 16/28 [00:13<00:13,  1.13s/it]
#  61% 17/28 [00:14<00:11,  1.04s/it]
#  64% 18/28 [00:15<00:09,  1.05it/s]
#  68% 19/28 [00:16<00:07,  1.15it/s]
#  71% 20/28 [00:17<00:07,  1.08it/s]
#  75% 21/28 [00:18<00:06,  1.08it/s]
#  79% 22/28 [00:18<00:05,  1.15it/s]
#  82% 23/28 [00:19<00:03,  1.34it/s]
#  86% 24/28 [00:19<00:02,  1.43it/s]
#  89% 25/28 [00:20<00:01,  1.70it/s]
#  93% 26/28 [00:20<00:01,  1.70it/s]
#  96% 27/28 [00:21<00:00,  1.66it/s]
#                                      A
# {'eval_loss': '1.233', 'eval_accuracy': '0.6009', 'eval_macro_f1': '0.4752', 'eval_runtime': '23.48', 'eval_samples_per_second': '9.498', 'eval_steps_per_second': '1.193', 'epoch': '4'}
#  80% 520/650 [27:47<05:39,  2.61s/it]
# 100% 28/28 [00:21<00:00,  1.90it/s]
#
# Writing model shards:   0% 0/1 [00:00<?, ?it/s]
# Writing model shards: 100% 1/1 [00:03<00:00,  3.49s/it]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 100% 650/650 [34:35<00:00,  2.45s/it]
#   0% 0/28 [00:00<?, ?it/s]
#   7% 2/28 [00:00<00:08,  2.96it/s]
#  11% 3/28 [00:00<00:07,  3.14it/s]
#  14% 4/28 [00:01<00:12,  1.89it/s]
#  18% 5/28 [00:02<00:12,  1.80it/s]
#  21% 6/28 [00:03<00:14,  1.49it/s]
#  25% 7/28 [00:04<00:16,  1.27it/s]
#  29% 8/28 [00:04<00:12,  1.62it/s]
#  32% 9/28 [00:05<00:13,  1.46it/s]
#  36% 10/28 [00:06<00:14,  1.26it/s]
#  39% 11/28 [00:07<00:14,  1.20it/s]
#  43% 12/28 [00:08<00:14,  1.11it/s]
#  46% 13/28 [00:09<00:14,  1.05it/s]
#  50% 14/28 [00:10<00:15,  1.08s/it]
#  54% 15/28 [00:12<00:14,  1.09s/it]
#  57% 16/28 [00:13<00:13,  1.13s/it]
#  61% 17/28 [00:13<00:10,  1.03it/s]
#  64% 18/28 [00:14<00:09,  1.11it/s]
#  68% 19/28 [00:15<00:07,  1.20it/s]
#  71% 20/28 [00:16<00:07,  1.12it/s]
#  75% 21/28 [00:17<00:06,  1.13it/s]
#  79% 22/28 [00:17<00:05,  1.18it/s]
#  82% 23/28 [00:18<00:03,  1.36it/s]
#  86% 24/28 [00:19<00:02,  1.45it/s]
#  89% 25/28 [00:19<00:01,  1.72it/s]
#  93% 26/28 [00:19<00:01,  1.72it/s]
#  96% 27/28 [00:20<00:00,  1.69it/s]
#                                      A
# {'eval_loss': '1.282', 'eval_accuracy': '0.6009', 'eval_macro_f1': '0.4864', 'eval_runtime': '22.6', 'eval_samples_per_second': '9.867', 'eval_steps_per_second': '1.239', 'epoch': '5'}
# 100% 650/650 [34:58<00:00,  2.45s/it]
# 100% 28/28 [00:20<00:00,  1.90it/s]
#
# Writing model shards:   0% 0/1 [00:00<?, ?it/s]
# Writing model shards: 100% 1/1 [00:05<00:00,  5.84s/it]
# There were missing keys in the checkpoint model loaded: ['roberta.embeddings.LayerNorm.weight', 'roberta.embeddings.LayerNorm.bias', 'roberta.encoder.layer.0.attention.output.LayerNorm.weight', 'roberta.encoder.layer.0.attention.output.LayerNorm.bias', 'roberta.encoder.layer.0.output.LayerNorm.weight', 'roberta.encoder.layer.0.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.weight', 'roberta.encoder.layer.1.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.LayerNorm.weight', 'roberta.encoder.layer.1.output.LayerNorm.bias', 'roberta.encoder.layer.2.attention.output.LayerNorm.weight', 'roberta.encoder.layer.2.attention.output.LayerNorm.bias', 'roberta.encoder.layer.2.output.LayerNorm.weight', 'roberta.encoder.layer.2.output.LayerNorm.bias', 'roberta.encoder.layer.3.attention.output.LayerNorm.weight', 'roberta.encoder.layer.3.attention.output.LayerNorm.bias', 'roberta.encoder.layer.3.output.LayerNorm.weight', 'roberta.encoder.layer.3.output.LayerNorm.bias'].
# There were unexpected keys in the checkpoint model loaded: ['roberta.embeddings.LayerNorm.beta', 'roberta.embeddings.LayerNorm.gamma', 'roberta.encoder.layer.0.attention.output.LayerNorm.beta', 'roberta.encoder.layer.0.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.0.output.LayerNorm.beta', 'roberta.encoder.layer.0.output.LayerNorm.gamma', 'roberta.encoder.layer.1.attention.output.LayerNorm.beta', 'roberta.encoder.layer.1.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.1.output.LayerNorm.beta', 'roberta.encoder.layer.1.output.LayerNorm.gamma', 'roberta.encoder.layer.2.attention.output.LayerNorm.beta', 'roberta.encoder.layer.2.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.2.output.LayerNorm.beta', 'roberta.encoder.layer.2.output.LayerNorm.gamma', 'roberta.encoder.layer.3.attention.output.LayerNorm.beta', 'roberta.encoder.layer.3.attention.output.LayerNorm.gamma', 'roberta.encoder.layer.3.output.LayerNorm.beta', 'roberta.encoder.layer.3.output.LayerNorm.gamma'].
# {'train_runtime': '2115', 'train_samples_per_second': '2.459', 'train_steps_per_second': '0.307', 'train_loss': '0.8758', 'epoch': '5'}
# 100% 650/650 [35:14<00:00,  3.25s/it]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 100% 28/28 [00:19<00:00,  1.46it/s]
# Writing model shards: 100% 1/1 [00:06<00:00,  6.18s/it]
# Transformer training complete.
# Model: castorini/afriberta_small
# Run ID: afriberta_small
# Test macro F1: 0.4422

# %%
# !find reports -iname "*afriberta*" -type f -printf "%p  %s bytes\n"
# Out:
# reports/results/afriberta_small_train_stdout_20260523_142940.log  0 bytes
# reports/results/afriberta_base_train_stderr_20260523_141306.log  1399 bytes
# reports/results/afriberta_base_train_stdout_20260523_141306.log  0 bytes
# reports/results/afriberta_small_predictions.csv  37751 bytes
# reports/results/afriberta_small_train_stderr_20260523_142940.log  497 bytes
# reports/results/afriberta_small_metrics.json  1830 bytes
# reports/results/afriberta_base_train_stdout_20260523_141719.log  0 bytes
# reports/results/afriberta_base_train_stdout_20260523_142614.log  0 bytes
# reports/results/afriberta_base_train_stderr_20260523_141719.log  497 bytes
# reports/results/afriberta_base_train_stderr_20260523_142614.log  497 bytes
# reports/figures/afriberta_small_confusion_matrix.png  56258 bytes

# %%
from pathlib import Path

expected = [
    "reports/results/afriberta_small_metrics.json",
    "reports/results/afriberta_small_predictions.csv",
    "reports/figures/afriberta_small_confusion_matrix.png",
]

for file in expected:
    p = Path(file)
    print(file, "FOUND" if p.exists() else "MISSING", p.stat().st_size if p.exists() else "")
# Out:
# reports/results/afriberta_small_metrics.json FOUND 1830
# reports/results/afriberta_small_predictions.csv FOUND 37751
# reports/figures/afriberta_small_confusion_matrix.png FOUND 56258

# %%
import json

with open("reports/results/afriberta_small_metrics.json", "r") as f:
    metrics = json.load(f)

print(metrics["test_metrics"]["macro_f1"])
print(metrics["test_metrics"]["accuracy"])
# Out:
# 0.442156862745098
# 0.6205357142857143

# %%
# !python -m src.compare_models
# Out:
# Model comparison saved to reports/results/model_comparison.csv
# model_family                model_name         feature_set         split  macro_f1  accuracy  weighted_f1                    source_file
# classical_ml                  baseline                     external_test  0.260256  0.259868     0.250802 external_baseline_metrics.json
#  transformer castorini/afriberta_small subword_transformer          test  0.442157  0.620536     0.614982   afriberta_small_metrics.json
# classical_ml  best_baseline:linear_svm          char_tfidf          test  0.337077  0.616071     0.563834          baseline_metrics.json
#  transformer          xlm-roberta-base subword_transformer          test  0.299418  0.543860     0.574847       transformer_metrics.json
# classical_ml                linear_svm          char_tfidf    validation  0.486789  0.659193     0.636848          baseline_metrics.json
# classical_ml       logistic_regression      combined_tfidf    validation  0.465729  0.614350     0.604438          baseline_metrics.json
# classical_ml       logistic_regression          char_tfidf    validation  0.460737  0.578475     0.582555          baseline_metrics.json
# classical_ml                linear_svm          word_tfidf    validation  0.457155  0.632287     0.601057          baseline_metrics.json
# classical_ml                linear_svm      combined_tfidf    validation  0.453567  0.659193     0.625443          baseline_metrics.json
# classical_ml       logistic_regression          word_tfidf    validation  0.452296  0.605381     0.591255          baseline_metrics.json
# classical_ml             complement_nb          word_tfidf    validation  0.340913  0.623318     0.566469          baseline_metrics.json
# classical_ml             complement_nb      combined_tfidf    validation  0.312281  0.654709     0.556802          baseline_metrics.json
# classical_ml             complement_nb          char_tfidf    validation  0.304798  0.659193     0.552737          baseline_metrics.json
# classical_ml            multinomial_nb          char_tfidf    validation  0.269162  0.677130     0.546773          baseline_metrics.json
# classical_ml            multinomial_nb          word_tfidf    validation  0.268097  0.672646     0.544609          baseline_metrics.json
# classical_ml            multinomial_nb      combined_tfidf    validation  0.268097  0.672646     0.544609          baseline_metrics.json
