# %%
import pandas as pd 
EXPECTED_COLUMNS = {"id", "text", "sentiment_label", "include"}
def load_annotation_file(file_path: Path) -> pd.DataFrame:
    df = pd.read_csv(file_path)
    df = df.rename(
        columns={
            "Unnamed: 0": "id",
            "topic-label": "topic_label",
            "sentiment-label": "sentiment_label",
            "Include": "include",
        }
    )
    missing = EXPECTED_COLUMNS - set(df.columns)
    if missing:
        missing_cols = ", ".join(sorted(missing))
        raise ValueError(f"{file_path.name} is missing required columns: {missing_cols}")
    df = df.copy()
    df["source_file"] = file_path.name
    return df
# Out:
# /content/Sentiment_Analysis/src
# active_learning.py  evaluate_external.py  __init__.py	 train_baseline.py
# compare_models.py   evaluate.py		  preprocess.py  train_transformer.py
# data_utils.py	    features.py		  __pycache__

# %%
# Out:
# Traceback (most recent call last):
#   File "/content/Sentiment_Analysis/src/compare_models.py", line 8, in <module>
#     from .data_utils import build_paths, ensure_project_dirs
# ImportError: attempted relative import with no known parent package
