# %% [markdown]
# # Feature Importance
#
# This notebook generates a feature-importance table and bar chart for the saved baseline model. It is intended for interpretation of the traditional ML baseline only. Transformer models such as AfriBERTa require different explainability methods.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT
# Out:
# WindowsPath('c:/Users/vdchi/OneDrive/Documents/DATA SCIENCE/Sem5/Group Project/Prototyping 2')

# %%
from src.feature_importance import generate_feature_importance

outputs = generate_feature_importance(root=PROJECT_ROOT, top_n=15)
outputs
# Out:
# c:\Users\vdchi\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.8.0 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\vdchi\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.8.0 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
import pandas as pd

importance = pd.read_csv(outputs["csv_path"])
importance.head(20)
# Out:
#    class_label  rank feature feature_display    weight  absolute_weight
# 0     negative     1      mm              mm  0.679019         0.679019
# 1     negative     2      ku              ku  0.672939         0.672939
# 2     negative     3      ak       <space>ak  0.625788         0.625788
# 3     negative     4      ku       <space>ku  0.543284         0.543284
# 4     negative     5       k        <space>k  0.541089         0.541089
# 5     negative     6    poli            poli  0.537005         0.537005
# 6     negative     7      ut              ut  0.533186         0.533186
# 7     negative     8      wa       <space>wa  0.532615         0.532615
# 8     negative     9      po              po  0.513816         0.513816
# 9     negative    10      mw       <space>mw  0.474753         0.474753
# 10    negative    11      zi              zi  0.465620         0.465620
# 11    negative    12      a         a<space>  0.460822         0.460822
# ...

# %%
from IPython.display import Image, display

display(Image(filename=outputs["figure_path"]))

# %% [markdown]
# ## Interpretation Note
#
# These bars show features with the strongest positive coefficients for each sentiment class. They should be interpreted as statistical associations learned by the baseline model, not as universal language rules.
