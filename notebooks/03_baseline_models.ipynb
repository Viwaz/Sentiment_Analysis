# %% [markdown]
# # 03 Baseline Models
#
# Train TF-IDF baselines and compare validation and test performance.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import json

from src.train_baseline import train_and_score_models
from src.data_utils import build_paths

summary = train_and_score_models()
summary['best_validation_run']
# Out:
# {'feature_set': 'word_tfidf',
#  'model_name': 'logistic_regression',
#  'validation_metrics': {'accuracy': 0.7894736842105263,
#   'macro_f1': 0.5535714285714285,
#   'per_class': {'negative': {'precision': 1.0,
#     'recall': 0.3333333333333333,
#     'f1': 0.5,
#     'support': 3},
#    'neutral': {'precision': 0.3333333333333333,
#     'recall': 0.25,
#     'f1': 0.2857142857142857,
#     'support': 8},
#    'positive': {'precision': 0.84,
#     'recall': 0.9130434782608695,
#     'f1': 0.875,
#     'support': 46}},
#   'classification_report': {'negative': {'precision': 1.0,
#     'recall': 0.3333333333333333,
#     'f1-score': 0.5,
#     'support': 3.0},
#    'neutral': {'precision': 0.3333333333333333,
#     'recall': 0.25,
#     'f1-score': 0.2857142857142857,
#     'support': 8.0},
#    'positive': {'precision': 0.84,
#     'recall': 0.9130434782608695,
#     'f1-score': 0.875,
#     'support': 46.0},
#    'accuracy': 0.7894736842105263,
# ...

# %%
paths = build_paths()
print((paths.results_dir / 'baseline_metrics.json').read_text())
# Out:
# {
#   "best_validation_run": {
#     "feature_set": "word_tfidf",
#     "model_name": "logistic_regression",
#     "validation_metrics": {
#       "accuracy": 0.7894736842105263,
#       "macro_f1": 0.5535714285714285,
#       "per_class": {
#         "negative": {
#           "precision": 1.0,
#           "recall": 0.3333333333333333,
#           "f1": 0.5,
#           "support": 3
#         },
#         "neutral": {
#           "precision": 0.3333333333333333,
#           "recall": 0.25,
#           "f1": 0.2857142857142857,
#           "support": 8
#         },
#         "positive": {
#           "precision": 0.84,
#           "recall": 0.9130434782608695,
#           "f1": 0.875,
#           "support": 46
#         }
#       },
#       "classification_report": {
#         "negative": {
#           "precision": 1.0,
#           "recall": 0.3333333333333333,
#           "f1-score": 0.5,
#           "support": 3.0
#         },
#         "neutral": {
# ...
